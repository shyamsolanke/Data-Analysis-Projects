# %%
import pandas as pd
df = pd.read_csv("Crash_Reporting_-_Drivers_Data.csv")
# Out:
# C:\Users\shyam\AppData\Local\Temp\ipykernel_98240\3483609155.py:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Crash_Reporting_-_Drivers_Data.csv")

# %%
df.columns
# Out:
# Index(['Report Number', 'Local Case Number', 'Agency Name', 'ACRS Report Type',
#        'Crash Date/Time', 'Route Type', 'Road Name', 'Cross-Street Name',
#        'Off-Road Description', 'Municipality', 'Related Non-Motorist',
#        'Collision Type', 'Weather', 'Surface Condition', 'Light',
#        'Traffic Control', 'Driver Substance Abuse',
#        'Non-Motorist Substance Abuse', 'Person ID', 'Driver At Fault',
#        'Injury Severity', 'Circumstance', 'Driver Distracted By',
#        'Drivers License State', 'Vehicle ID', 'Vehicle Damage Extent',
#        'Vehicle First Impact Location', 'Vehicle Body Type',
#        'Vehicle Movement', 'Vehicle Going Dir', 'Speed Limit',
#        'Driverless Vehicle', 'Parked Vehicle', 'Vehicle Year', 'Vehicle Make',
#        'Vehicle Model', 'Latitude', 'Longitude', 'Location'],
#       dtype='object')

# %%
# some of these columns can be combined
df["Driver Distracted By"].value_counts()
# Out:
# Driver Distracted By
# NOT DISTRACTED                                       106718
# UNKNOWN                                               32804
# LOOKED BUT DID NOT SEE                                21547
# Not Distracted                                         9557
# INATTENTIVE OR LOST IN THOUGHT                         4320
# Unknown                                                3415
# OTHER DISTRACTION                                      3245
# DISTRACTED BY OUTSIDE PERSON OBJECT OR EVENT            970
# Other Action (looking away from task, etc.)             459
# BY OTHER OCCUPANTS                                      418
# OTHER CELLULAR PHONE RELATED                            372
# OTHER ELECTRONIC DEVICE (NAVIGATIONAL PALM PILOT)       325
# TALKING OR LISTENING TO CELLULAR PHONE                  282
# NO DRIVER PRESENT                                       280
# BY MOVING OBJECT IN VEHICLE                             212
# ...

# %%
# we can do EDA on specifically for parked vehicle (reason for accident on parked Vehicle -  Satyam)
df["Parked Vehicle"].value_counts()
# Out:
# Parked Vehicle
# No     182075
# Yes      2961
# Name: count, dtype: int64

# %%
# Again categorize can be combined
df["Vehicle Body Type"].value_counts()
# Out:
# Vehicle Body Type
# PASSENGER CAR                                                119112
# (SPORT) UTILITY VEHICLE                                       15990
# Passenger Car                                                  9240
# PICKUP TRUCK                                                   6787
# VAN                                                            4958
# TRANSIT BUS                                                    3642
# SCHOOL BUS                                                     2975
# Sport Utility Vehicle                                          2340
# POLICE VEHICLE/NON EMERGENCY                                   2119
# OTHER LIGHT TRUCKS (10,000LBS (4,536KG) OR LESS)               1909
# CARGO VAN/LIGHT TRUCK 2 AXLES (OVER 10,000LBS (4,536 KG))      1858
# OTHER                                                          1539
# POLICE VEHICLE/EMERGENCY                                       1497
# MEDIUM/HEAVY TRUCKS 3 AXLES (OVER 10,000LBS (4,536KG))         1469
# ...

# %%
# column can be removed
df["Driverless Vehicle"].value_counts()
# Out:
# Driverless Vehicle
# No         185829
# Unknown       741
# Name: count, dtype: int64

# %%
df["Vehicle Make"].value_counts()
# Out:
# Vehicle Make
# TOYOTA         25905
# HONDA          20976
# FORD           18478
# NISSAN          9381
# TOYT            8841
#                ...
# CHEVVAL2010        1
# OLDSMOBIL          1
# DAODGE             1
# MITUS              1
# DORSEY             1
# Name: count, Length: 1931, dtype: int64

# %%
#
df["Collision Type"].value_counts()
# Out:
# Collision Type
# SAME DIR REAR END                55761
# STRAIGHT MOVEMENT ANGLE          30342
# OTHER                            19030
# SAME DIRECTION SIDESWIPE         16227
# SINGLE VEHICLE                   15873
# HEAD ON LEFT TURN                12926
# Front to Rear                     4316
# SAME DIRECTION RIGHT TURN         3832
# HEAD ON                           3786
# SAME DIRECTION LEFT TURN          3715
# OPPOSITE DIRECTION SIDESWIPE      2883
# Angle                             2688
# Sideswipe, Same Direction         2284
# ANGLE MEETS LEFT TURN             2033
# Single Vehicle                    1654
# ANGLE MEETS RIGHT TURN            1204
# Other                              994
# Front to Front                     839
# Rear To Side                       805
# SAME DIR REND LEFT TURN            743
# SAME DIR REND RIGHT TURN           720
# SAME DIR BOTH LEFT TURN            719
# UNKNOWN                            718
# ...

# %%
df["Off-Road Description"].value_counts()
# Out:
# Off-Road Description
# PARKING LOT                                                                         132
# PARKING LOT OF 11160 VEIRS MILL RD                                                   15
# PARKING LOT OF 10901 WESTLAKE DR                                                     13
# PARKING LOT OF 11160 VEIRS MILL ROAD                                                 12
# PARKING LOT OF 11920 BOURNEFIELD WAY                                                 12
#                                                                                    ...
# PARKING LOT OUTSIDE 9639 LOST KNIFE RD, MONTGOMERY VILLAGE, MD.                       1
# PARKING LOT OF 8110 GEORGIA AVE SILVER SPRING MD 20091                                1
# REAR PARKING LOT STATION 10 FIREHOUSE                                                 1
# 10500 TUCKERMAN LN.  PARKING LOT DROVE THROUGH GRASS TO LOWER LOADING DOCK AREA.      1
# ...

# %%
df["Speed Limit"].value_counts()
# Out:
# Speed Limit
# 35    55396
# 40    35569
# 25    26206
# 30    25608
# 45    13109
# 15     6369
# 0      6024
# 50     4998
# 5      4315
# 55     4286
# 10     3178
# 20     1363
# 60       82
# 65       58
# 70        8
# 75        1
# Name: count, dtype: int64

# %%
df['Route Type'].value_counts()
# Out:
# Route Type
# Maryland (State)          77079
# County                    55574
# Municipality               9380
# US (State)                 8237
# County Route               5133
# Maryland (State) Route     4888
# Interstate (State)         3338
# Other Public Roadway       1244
# Municipality Route         1061
# Ramp                        843
# Government                  627
# Local Route                 280
# Bicycle Route               171
# Spur                        133
# Private Route               119
# Crossover                    83
# Government Route             59
# Service Road                 45
# Unknown                      20
# Name: count, dtype: int64

# %%
df["Driver Substance Abuse"].value_counts()
# Out:
# Driver Substance Abuse
# NONE DETECTED                                          122547
# Not Suspect of Alcohol Use, Not Suspect of Drug Use     12422
# UNKNOWN                                                 11990
# ALCOHOL PRESENT                                          4087
# Unknown, Unknown                                         1513
# ALCOHOL CONTRIBUTED                                      1435
# Suspect of Alcohol Use, Not Suspect of Drug Use           369
# ILLEGAL DRUG PRESENT                                      259
# MEDICATION PRESENT                                        117
# ILLEGAL DRUG CONTRIBUTED                                  102
# COMBINED SUBSTANCE PRESENT                                 92
# MEDICATION CONTRIBUTED                                     64
# OTHER                                                      59
# COMBINATION CONTRIBUTED                                    47
# Suspect of Alcohol Use, Unknown                            44
# ...

# %%
df["Surface Condition"].value_counts()
# Out:
# Surface Condition
# DRY                         120577
# WET                          28431
# Dry                          10699
# Wet                           2188
# ICE                           1058
# SNOW                           938
# UNKNOWN                        509
# SLUSH                          204
# OTHER                          164
# Snow                            88
# Ice/Frost                       67
# MUD, DIRT, GRAVEL               46
# WATER(STANDING/MOVING)          41
# OIL                             28
# Other                           26
# Slush                           26
# Water (standing, moving)         6
# SAND                             4
# Sand                             4
# Mud, Dirt, Gravel                3
# Name: count, dtype: int64

# %%
df["Vehicle Body Type"].fillna("unknown", inplace = True)
# Out:
# C:\Users\shyam\AppData\Local\Temp\ipykernel_98240\2676313373.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Vehicle Body Type"].fillna("unknown", inplace = True)

# %%
for index, row in df.iterrows():
    try:
        # Perform your operation here
        result = str.lower(row["Vehicle Body Type"])
        # print(result)
    except Exception as e:
        print(f"Error at index {index}, value {row['Vehicle Body Type']}: {e}")
# Out:
# Error at index 23, value nan: descriptor 'lower' for 'str' objects doesn't apply to a 'float' object
# Error at index 74, value nan: descriptor 'lower' for 'str' objects doesn't apply to a 'float' object
# Error at index 77, value nan: descriptor 'lower' for 'str' objects doesn't apply to a 'float' object
# Error at index 143, value nan: descriptor 'lower' for 'str' objects doesn't apply to a 'float' object
# Error at index 197, value nan: descriptor 'lower' for 'str' objects doesn't apply to a 'float' object
# Error at index 443, value nan: descriptor 'lower' for 'str' objects doesn't apply to a 'float' object
# Error at index 445, value nan: descriptor 'lower' for 'str' objects doesn't apply to a 'float' object
# Error at index 477, value nan: descriptor 'lower' for 'str' objects doesn't apply to a 'float' object
# Error at index 578, value nan: descriptor 'lower' for 'str' objects doesn't apply to a 'float' object
# ...

# %%
df["Vehicle Body Type"] = df["Vehicle Body Type"].apply(lambda x: str.lower(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[314], line 1
# ----> 1 df["Vehicle Body Type"] = df["Vehicle Body Type"].apply(lambda x: str.lower(x))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
# ...

# %%
df["Vehicle Body Type"].value_counts()
# Out:
# Vehicle Body Type
# PASSENGER CAR                                                119112
# (SPORT) UTILITY VEHICLE                                       15990
# Passenger Car                                                  9240
# PICKUP TRUCK                                                   6787
# VAN                                                            4958
# TRANSIT BUS                                                    3642
# SCHOOL BUS                                                     2975
# Sport Utility Vehicle                                          2340
# POLICE VEHICLE/NON EMERGENCY                                   2119
# OTHER LIGHT TRUCKS (10,000LBS (4,536KG) OR LESS)               1909
# CARGO VAN/LIGHT TRUCK 2 AXLES (OVER 10,000LBS (4,536 KG))      1858
# OTHER                                                          1539
# POLICE VEHICLE/EMERGENCY                                       1497
# MEDIUM/HEAVY TRUCKS 3 AXLES (OVER 10,000LBS (4,536KG))         1469
# ...

# %%
df.columns
# Out:
# Index(['Report Number', 'Local Case Number', 'Agency Name', 'ACRS Report Type',
#        'Crash Date/Time', 'Route Type', 'Road Name', 'Cross-Street Name',
#        'Off-Road Description', 'Municipality', 'Related Non-Motorist',
#        'Collision Type', 'Weather', 'Surface Condition', 'Light',
#        'Traffic Control', 'Driver Substance Abuse',
#        'Non-Motorist Substance Abuse', 'Person ID', 'Driver At Fault',
#        'Injury Severity', 'Circumstance', 'Driver Distracted By',
#        'Drivers License State', 'Vehicle ID', 'Vehicle Damage Extent',
#        'Vehicle First Impact Location', 'Vehicle Body Type',
#        'Vehicle Movement', 'Vehicle Going Dir', 'Speed Limit',
#        'Driverless Vehicle', 'Parked Vehicle', 'Vehicle Year', 'Vehicle Make',
#        'Vehicle Model', 'Latitude', 'Longitude', 'Location'],
#       dtype='object')

# %%
df["Surface Condition"].fillna("unknown", inplace=True)
df["Surface Condition"] = df["Surface Condition"].apply(lambda x: str.lower(x))
# Out:
# C:\Users\shyam\AppData\Local\Temp\ipykernel_98240\638426583.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Surface Condition"].fillna("unknown", inplace=True)

# %%
df["Surface Condition"].value_counts()
# Out:
# Surface Condition
# dry                         131276
# wet                          30619
# unknown                      21972
# ice                           1058
# snow                          1026
# slush                          230
# other                          190
# ice/frost                       67
# mud, dirt, gravel               49
# water(standing/moving)          41
# oil                             28
# sand                             8
# water (standing, moving)         6
# Name: count, dtype: int64

# %%
df["Surface Condition"] = df["Surface Condition"].str.replace("ice/frost","ice")
# df["Surface Condition"] = df["Surface Condition"].str.replace("mud, dirt, gravel","ice")
df["Surface Condition"] = df["Surface Condition"].str.replace("water (standing, moving)", "water(standing/moving)")

# %%
df["Driver Substance Abuse"].value_counts()
# Out:
# Driver Substance Abuse
# NONE DETECTED                                 122547
# UNKNOWN                                        26041
# only alcohol                                    5522
# only alcohol suspect                             413
# ILLEGAL DRUG PRESENT                             259
# only drug                                        122
# MEDICATION PRESENT                               117
# COMBINED SUBSTANCE PRESENT                        92
# MEDICATION CONTRIBUTED                            64
# COMBINATION CONTRIBUTED                           47
# Suspect of Alcohol Use Suspect of Drug Use        26
# Name: count, dtype: int64

# %%
# suspect_only_alcohol = "/bSuspect of Alcohol Use, Not Suspect of Drug Use/b|/bSuspect of Alcohol Use, Unknown/b"
# df["Driver Substance Abuse"] = df["Driver Substance Abuse"].str.replace("ALCOHOL PRESENT|ALCOHOL CONTRIBUTED", "only alcohol", regex=True)
# df["Driver Substance Abuse"] = df["Driver Substance Abuse"].str.replace("Suspect of Alcohol Use Not Suspect of Drug Use", "only alcohol suspect", regex=True)

# %%
# df["Driver Substance Abuse"] = df["Driver Substance Abuse"].str.replace("Not Suspect of Alcohol Use Unknown", "UNKNOWN")
# df["Driver Substance Abuse"] = df["Driver Substance Abuse"].str.replace("Not Suspect of Alcohol Use Not Suspect of Drug Use", "UNKNOWN")
# df["Driver Substance Abuse"] = df["Driver Substance Abuse"].str.replace("Not Suspect of Alcohol Use Suspect of Drug Use", "NONE DETECTED")

# %%
df["Driver Substance Abuse"].unique()
# Out:
# array(['NONE DETECTED', 'UNKNOWN', nan, 'only alcohol',
#        'COMBINATION CONTRIBUTED', 'combined suspect', 'only drug',
#        'only drug suspect', 'MEDICATION CONTRIBUTED',
#        'MEDICATION PRESENT', 'only alcohol suspect'], dtype=object)

# %%
# df["Driver Substance Abuse"] = df["Driver Substance Abuse"].str.replace(",", "")

# %%
# df["Driver Substance Abuse"] = df["Driver Substance Abuse"].str.replace("Unknown Not Suspect of Drug Use", "UNKNOWN")

# %%
# df["Driver Substance Abuse"] = df["Driver Substance Abuse"].str.replace("OTHER", "UNKNOWN")

# %%
# df["Driver Substance Abuse"] = df["Driver Substance Abuse"].str.replace("ILLEGAL DRUG CONTRIBUTED", "only drug")
# df["Driver Substance Abuse"] = df["Driver Substance Abuse"].str.replace("Unknown Suspect of Drug Use", "only drug")
# df["Driver Substance Abuse"] = df["Driver Substance Abuse"].str.replace("Not Suspect of Alcohol Use Suspect of Drug Use", "only drug")

# %%
# df["Driver Substance Abuse"] = df["Driver Substance Abuse"].str.replace("ILLEGAL DRUG PRESENT", "only drug suspect")

# %%
# df.to_csv("EDA_1.csv")

# %%
# df["Driver Substance Abuse"] = df["Driver Substance Abuse"].str.replace("COMBINED SUBSTANCE PRESENT", "combined suspect")
# df["Driver Substance Abuse"] = df["Driver Substance Abuse"].str.replace("Suspect of Alcohol Use Suspect of Drug Use", "combined suspect")
